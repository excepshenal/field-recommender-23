# %% [markdown]
# # LightGCN - simplified GCN model for recommendation
#
# This notebook serves as an introduction to LightGCN [1], which is an simple, linear and neat Graph Convolution Network (GCN) [3] model for recommendation.

# %% [markdown]
# ## 0 Global Settings and Imports

# %%
import sys
import os
import pandas as pd
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

from recommenders.utils.timer import Timer
from recommenders.models.deeprec.models.graphrec.lightgcn import LightGCN
from recommenders.models.deeprec.DataModel.ImplicitCF import ImplicitCF
from recommenders.datasets import movielens
from recommenders.datasets.python_splitters import python_stratified_split
from recommenders.evaluation.python_evaluation import map_at_k, ndcg_at_k, precision_at_k, recall_at_k
from recommenders.utils.constants import SEED as DEFAULT_SEED
from recommenders.models.deeprec.deeprec_utils import prepare_hparams

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.8.15 | packaged by conda-forge | (default, Nov 22 2022, 08:51:59)
# [Clang 14.0.6 ]
# Pandas version: 1.5.3
# Tensorflow version: 2.9.1

# %%
DATA_FILE_NAME = "../Data/20230721T041206_sales_2023_basic_single_events_removed.csv"
THIS_ENGINE_NAME = "lightgcn_field_3"

# country
COUNTRY = "nigeria"

# top k items to recommend, for train & test
TOP_K_SPLIT_TRAIN_TEST = 10
# top k items to recommend, for final product recommendation output
TOP_K_WHOLE = 100
EXTRA_COLS = False

# fraction of location_skus to include in training dataset
TRAIN_FRAC = 0.75

# Model parameters
EPOCHS = 75
BATCH_SIZE = 1024
N_LAYERS = 3
LEARNING_RATE = 0.005
EVAL_EPOCH = 5

SEED = DEFAULT_SEED  # Set None for non-deterministic results

yaml_file = THIS_ENGINE_NAME + "_hparams.yaml"
# user_file = "../../tests/resources/deeprec/lightgcn/user_embeddings.csv"
# item_file = "../../tests/resources/deeprec/lightgcn/item_embeddings.csv"

# %% [markdown]
# ## 1 Data
#
# ### 1.1 Load and split data
#
# We split the full dataset into a `train` and `test` dataset to evaluate performance of the algorithm against a held-out set not seen during training. Because SAR (typo?) generates recommendations based on user preferences, all users that are in the test set must also exist in the training set. For this case, we can use the provided `python_stratified_split` function which holds out a percentage (in this case 25%) of items from each user, but ensures all users are in both `train` and `test` datasets. Other options are available in the `dataset.python_splitters` module which provide more control over how the split occurs.

# %%
df_all_cols = pd.read_csv(DATA_FILE_NAME)
df_all_cols = df_all_cols[df_all_cols["country"] == COUNTRY]

df = df_all_cols[["location_id", "product", "sl_sold"]]
df.rename(columns = {"location_id": "userID", "product": "itemID", "sl_sold": "rating"}, inplace = True)

df.head()
# Out:
# /var/folders/pz/g0trckmn61v44xkm8xvfx0n00000gn/T/ipykernel_58194/3279382176.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.rename(columns = {"location_id": "userID", "product": "itemID", "sl_sold": "rating"}, inplace = True)
#                                      userID  \
# 509  "01aa6102-a054-4f25-a747-a39a4ea86769"
# 510  "01aa6102-a054-4f25-a747-a39a4ea86769"
# 511  "01aa6102-a054-4f25-a747-a39a4ea86769"
# 512  "01aa6102-a054-4f25-a747-a39a4ea86769"
# 513  "01aa6102-a054-4f25-a747-a39a4ea86769"
#
#                                   itemID  rating
# 509                       Mixanal Tablet       1
# 510  Emzor Paracetamol 500mg Tablets x96       3
# 511  Syrup Paracetamol 125mg/5ml (Emzor)      20
# 512                 Em-Vit-C 100ml Syrup       2
# 513                  Funbact A 30g Cream       2

# %%
train, test = python_stratified_split(df, ratio = TRAIN_FRAC, seed = SEED)

# %% [markdown]
# ### 1.2 Process data
#
# `ImplicitCF` is a class that intializes and loads data for the training process. During the initialization of this class, user IDs and item IDs are reindexed, ratings greater than zero are converted into implicit positive interaction, and adjacency matrix $R$ of user-item graph is created. Some important methods of `ImplicitCF` are:
#
# `get_norm_adj_mat`, load normalized adjacency matrix of user-item graph if it already exists in `adj_dir`, otherwise call `create_norm_adj_mat` to create the matrix and save the matrix if `adj_dir` is not `None`. This method will be called during the initialization process of LightGCN model.
#
# `create_norm_adj_mat`, create normalized adjacency matrix of user-item graph by calculating $D^{-\frac{1}{2}} A D^{-\frac{1}{2}}$, where $\mathbf{A}=\left(\begin{array}{cc}\mathbf{0} & \mathbf{R} \\ \mathbf{R}^{T} & \mathbf{0}\end{array}\right)$.
#
# `train_loader`, generate a batch of training data — sample a batch of users and then sample one positive item and one negative item for each user. This method will be called before each epoch of the training process.

# %%
data = ImplicitCF(train=train, test=test, seed=SEED)
# Out:
# /Users/DanielShen/opt/anaconda3/envs/microsoft_rec/lib/python3.8/site-packages/recommenders/models/deeprec/DataModel/ImplicitCF.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = train if test is None else train.append(test)

# %% [markdown]
# ### 1.3 Prepare hyper-parameters
#
# Important parameters of `LightGCN` model are:
#
# `data`, initialized LightGCNDataset object.
#
# `epochs`, number of epochs for training.
#
# `n_layers`, number of layers of the model.
#
# `eval_epoch`, if it is not None, evaluation metrics will be calculated on test set every "eval_epoch" epochs. In this way, we can observe the effect of the model during the training process.
#
# `top_k`, the number of items to be recommended for each user when calculating ranking metrics.
#
# A complete list of parameters can be found in `yaml_file`. We use `prepare_hparams` to read the yaml file and prepare a full set of parameters for the model. Parameters passed as the function's parameters will overwrite yaml settings.

# %%
hparams = prepare_hparams(yaml_file,
                          n_layers=N_LAYERS,
                          batch_size=BATCH_SIZE,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE,
                          eval_epoch=EVAL_EPOCH,
                          top_k=TOP_K_SPLIT_TRAIN_TEST,
                         )

# %% [markdown]
# ## 2 Train model
#
# With data and parameters prepared, we can create the LightGCN model.
#
# To train the model, we simply need to call the `fit()` method.

# %%
model = LightGCN(hparams, data, seed=SEED)
# Out:
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# 2023-08-02 13:57:51.805870: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-02 13:57:51.855613: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:354] MLIR V1 optimization pass is not enabled

# %%
with Timer() as train_time:
    model.fit()

print("Took {} seconds for training.".format(train_time.interval))
# Out:
# Epoch 1 (train)1.2s: train loss = 0.62590 = (mf)0.62584 + (embed)0.00007
# Epoch 2 (train)1.0s: train loss = 0.38232 = (mf)0.38193 + (embed)0.00038
# Epoch 3 (train)1.1s: train loss = 0.33318 = (mf)0.33258 + (embed)0.00060
# Epoch 4 (train)1.1s: train loss = 0.30885 = (mf)0.30817 + (embed)0.00069
# Epoch 5 (train)1.1s + (eval)0.2s: train loss = 0.27948 = (mf)0.27867 + (embed)0.00081, recall = 0.07149, ndcg = 0.23194, precision = 0.22443, map = 0.03657
# Epoch 6 (train)1.3s: train loss = 0.26046 = (mf)0.25951 + (embed)0.00095
# Epoch 7 (train)1.0s: train loss = 0.25233 = (mf)0.25126 + (embed)0.00107
# Epoch 8 (train)1.0s: train loss = 0.24182 = (mf)0.24063 + (embed)0.00119
# Epoch 9 (train)1.1s: train loss = 0.23063 = (mf)0.22932 + (embed)0.00131
# Epoch 10 (train)1.1s + (eval)0.3s: train loss = 0.22503 = (mf)0.22361 + (embed)0.00142, recall = 0.07670, ndcg = 0.24541, precision = 0.23652, map = 0.03933
# Epoch 11 (train)1.1s: train loss = 0.21280 = (mf)0.21126 + (embed)0.00154
# Epoch 12 (train)1.1s: train loss = 0.21094 = (mf)0.20929 + (embed)0.00166
# Epoch 13 (train)0.9s: train loss = 0.20219 = (mf)0.20042 + (embed)0.00177
# Epoch 14 (train)1.0s: train loss = 0.19594 = (mf)0.19406 + (embed)0.00188
# Epoch 15 (train)1.0s + (eval)0.1s: train loss = 0.18676 = (mf)0.18475 + (embed)0.00201, recall = 0.08441, ndcg = 0.25946, precision = 0.25264, map = 0.04317
# Epoch 16 (train)0.9s: train loss = 0.18096 = (mf)0.17882 + (embed)0.00214
# Epoch 17 (train)0.9s: train loss = 0.17473 = (mf)0.17246 + (embed)0.00226
# Epoch 18 (train)0.8s: train loss = 0.16858 = (mf)0.16620 + (embed)0.00238
# Epoch 19 (train)0.8s: train loss = 0.16296 = (mf)0.16046 + (embed)0.00250
# Epoch 20 (train)0.8s + (eval)0.1s: train loss = 0.15851 = (mf)0.15590 + (embed)0.00262, recall = 0.09090, ndcg = 0.26997, precision = 0.25894, map = 0.04677
# Epoch 21 (train)0.8s: train loss = 0.15699 = (mf)0.15423 + (embed)0.00276
# Epoch 22 (train)0.8s: train loss = 0.15292 = (mf)0.15004 + (embed)0.00288
# Epoch 23 (train)0.8s: train loss = 0.14683 = (mf)0.14383 + (embed)0.00300
# Epoch 24 (train)0.8s: train loss = 0.14303 = (mf)0.13990 + (embed)0.00312
# Epoch 25 (train)0.8s + (eval)0.1s: train loss = 0.14062 = (mf)0.13737 + (embed)0.00326, recall = 0.08833, ndcg = 0.26586, precision = 0.25793, map = 0.04571
# Epoch 26 (train)0.8s: train loss = 0.13889 = (mf)0.13550 + (embed)0.00339
# Epoch 27 (train)0.8s: train loss = 0.13555 = (mf)0.13204 + (embed)0.00351
# Epoch 28 (train)0.8s: train loss = 0.13527 = (mf)0.13166 + (embed)0.00362
# Epoch 29 (train)0.8s: train loss = 0.12614 = (mf)0.12241 + (embed)0.00373
# Epoch 30 (train)0.8s + (eval)0.1s: train loss = 0.12386 = (mf)0.11999 + (embed)0.00387, recall = 0.09150, ndcg = 0.27731, precision = 0.26801, map = 0.04965
# Epoch 31 (train)0.8s: train loss = 0.12338 = (mf)0.11940 + (embed)0.00398
# Epoch 32 (train)0.8s: train loss = 0.12085 = (mf)0.11678 + (embed)0.00407
# Epoch 33 (train)0.8s: train loss = 0.11760 = (mf)0.11339 + (embed)0.00421
# Epoch 34 (train)0.8s: train loss = 0.11811 = (mf)0.11380 + (embed)0.00431
# Epoch 35 (train)0.8s + (eval)0.1s: train loss = 0.11557 = (mf)0.11112 + (embed)0.00445, recall = 0.08816, ndcg = 0.27289, precision = 0.26348, map = 0.04762
# Epoch 36 (train)0.8s: train loss = 0.11047 = (mf)0.10594 + (embed)0.00454
# Epoch 37 (train)0.8s: train loss = 0.11154 = (mf)0.10690 + (embed)0.00463
# Epoch 38 (train)0.8s: train loss = 0.11388 = (mf)0.10914 + (embed)0.00475
# Epoch 39 (train)0.8s: train loss = 0.10981 = (mf)0.10497 + (embed)0.00484
# Epoch 40 (train)0.8s + (eval)0.1s: train loss = 0.10547 = (mf)0.10052 + (embed)0.00495, recall = 0.09178, ndcg = 0.27505, precision = 0.26524, map = 0.04794
# Epoch 41 (train)0.8s: train loss = 0.10507 = (mf)0.10004 + (embed)0.00503
# Epoch 42 (train)0.8s: train loss = 0.10230 = (mf)0.09714 + (embed)0.00516
# Epoch 43 (train)0.8s: train loss = 0.10148 = (mf)0.09623 + (embed)0.00525
# Epoch 44 (train)0.8s: train loss = 0.10162 = (mf)0.09628 + (embed)0.00534
# Epoch 45 (train)0.8s + (eval)0.1s: train loss = 0.09994 = (mf)0.09450 + (embed)0.00544, recall = 0.09137, ndcg = 0.27544, precision = 0.26045, map = 0.04941
# Epoch 46 (train)0.8s: train loss = 0.09695 = (mf)0.09142 + (embed)0.00553
# Epoch 47 (train)0.8s: train loss = 0.09863 = (mf)0.09300 + (embed)0.00563
# Epoch 48 (train)0.8s: train loss = 0.09920 = (mf)0.09348 + (embed)0.00572
# Epoch 49 (train)0.8s: train loss = 0.09718 = (mf)0.09139 + (embed)0.00579
# Epoch 50 (train)0.8s + (eval)0.1s: train loss = 0.09247 = (mf)0.08658 + (embed)0.00589, recall = 0.09183, ndcg = 0.28064, precision = 0.27053, map = 0.05008
# Epoch 51 (train)0.8s: train loss = 0.09325 = (mf)0.08727 + (embed)0.00598
# Epoch 52 (train)0.8s: train loss = 0.09278 = (mf)0.08671 + (embed)0.00607
# Epoch 53 (train)0.8s: train loss = 0.09215 = (mf)0.08598 + (embed)0.00616
# Epoch 54 (train)0.8s: train loss = 0.09277 = (mf)0.08652 + (embed)0.00625
# Epoch 55 (train)0.8s + (eval)0.1s: train loss = 0.08878 = (mf)0.08245 + (embed)0.00633, recall = 0.08746, ndcg = 0.27887, precision = 0.26524, map = 0.05013
# Epoch 56 (train)0.8s: train loss = 0.08901 = (mf)0.08259 + (embed)0.00642
# Epoch 57 (train)0.8s: train loss = 0.08813 = (mf)0.08160 + (embed)0.00652
# Epoch 58 (train)0.8s: train loss = 0.08680 = (mf)0.08020 + (embed)0.00661
# Epoch 59 (train)0.8s: train loss = 0.08472 = (mf)0.07801 + (embed)0.00671
# Epoch 60 (train)0.8s + (eval)0.1s: train loss = 0.08574 = (mf)0.07897 + (embed)0.00678, recall = 0.08555, ndcg = 0.27092, precision = 0.25668, map = 0.04803
# Epoch 61 (train)0.8s: train loss = 0.08475 = (mf)0.07790 + (embed)0.00686
# Epoch 62 (train)0.8s: train loss = 0.08297 = (mf)0.07603 + (embed)0.00694
# Epoch 63 (train)0.8s: train loss = 0.08471 = (mf)0.07770 + (embed)0.00701
# Epoch 64 (train)0.8s: train loss = 0.08213 = (mf)0.07504 + (embed)0.00709
# Epoch 65 (train)0.8s + (eval)0.1s: train loss = 0.07974 = (mf)0.07255 + (embed)0.00718, recall = 0.08759, ndcg = 0.27721, precision = 0.26625, map = 0.04930
# Epoch 66 (train)0.8s: train loss = 0.07854 = (mf)0.07127 + (embed)0.00727
# Epoch 67 (train)0.8s: train loss = 0.08257 = (mf)0.07523 + (embed)0.00734
# Epoch 68 (train)0.8s: train loss = 0.07691 = (mf)0.06949 + (embed)0.00742
# Epoch 69 (train)0.8s: train loss = 0.07793 = (mf)0.07041 + (embed)0.00752
# Epoch 70 (train)0.8s + (eval)0.1s: train loss = 0.07938 = (mf)0.07184 + (embed)0.00755, recall = 0.08857, ndcg = 0.27631, precision = 0.26297, map = 0.04949
# Epoch 71 (train)0.8s: train loss = 0.07457 = (mf)0.06690 + (embed)0.00767
# Epoch 72 (train)0.8s: train loss = 0.07459 = (mf)0.06686 + (embed)0.00774
# Epoch 73 (train)0.8s: train loss = 0.07371 = (mf)0.06590 + (embed)0.00781
# Epoch 74 (train)0.8s: train loss = 0.07282 = (mf)0.06493 + (embed)0.00789
# Epoch 75 (train)0.8s + (eval)0.1s: train loss = 0.07529 = (mf)0.06733 + (embed)0.00795, recall = 0.08710, ndcg = 0.27624, precision = 0.26222, map = 0.04923
# Epoch 76 (train)0.8s: train loss = 0.07333 = (mf)0.06526 + (embed)0.00806
# Epoch 77 (train)0.8s: train loss = 0.07452 = (mf)0.06639 + (embed)0.00813
# Epoch 78 (train)0.8s: train loss = 0.07282 = (mf)0.06463 + (embed)0.00819
# Epoch 79 (train)0.8s: train loss = 0.07132 = (mf)0.06305 + (embed)0.00827
# Epoch 80 (train)0.8s + (eval)0.1s: train loss = 0.07075 = (mf)0.06240 + (embed)0.00835, recall = 0.08583, ndcg = 0.27568, precision = 0.25869, map = 0.04900
# Epoch 81 (train)0.8s: train loss = 0.06983 = (mf)0.06138 + (embed)0.00845
# Epoch 82 (train)0.8s: train loss = 0.07037 = (mf)0.06185 + (embed)0.00852
# Epoch 83 (train)0.8s: train loss = 0.06966 = (mf)0.06111 + (embed)0.00856
# Epoch 84 (train)0.8s: train loss = 0.06649 = (mf)0.05780 + (embed)0.00869
# Epoch 85 (train)0.8s + (eval)0.1s: train loss = 0.06672 = (mf)0.05798 + (embed)0.00873, recall = 0.08951, ndcg = 0.28183, precision = 0.26650, map = 0.05019
# Epoch 86 (train)0.8s: train loss = 0.06799 = (mf)0.05917 + (embed)0.00882
# Epoch 87 (train)0.8s: train loss = 0.06729 = (mf)0.05839 + (embed)0.00890
# Epoch 88 (train)0.8s: train loss = 0.06557 = (mf)0.05662 + (embed)0.00895
# Epoch 89 (train)0.8s: train loss = 0.06545 = (mf)0.05641 + (embed)0.00905
# Epoch 90 (train)0.8s + (eval)0.1s: train loss = 0.06536 = (mf)0.05625 + (embed)0.00911, recall = 0.08559, ndcg = 0.27657, precision = 0.26322, map = 0.04946
# Epoch 91 (train)0.8s: train loss = 0.06385 = (mf)0.05466 + (embed)0.00919
# Epoch 92 (train)0.8s: train loss = 0.06342 = (mf)0.05417 + (embed)0.00925
# Epoch 93 (train)0.8s: train loss = 0.06430 = (mf)0.05501 + (embed)0.00929
# Epoch 94 (train)0.8s: train loss = 0.06436 = (mf)0.05498 + (embed)0.00937
# Epoch 95 (train)0.8s + (eval)0.1s: train loss = 0.06333 = (mf)0.05389 + (embed)0.00945, recall = 0.08705, ndcg = 0.27457, precision = 0.26423, map = 0.04834
# Epoch 96 (train)0.8s: train loss = 0.06411 = (mf)0.05459 + (embed)0.00952
# Epoch 97 (train)0.8s: train loss = 0.06171 = (mf)0.05213 + (embed)0.00958
# Epoch 98 (train)0.8s: train loss = 0.05996 = (mf)0.05029 + (embed)0.00967
# Epoch 99 (train)0.8s: train loss = 0.05960 = (mf)0.04989 + (embed)0.00970
# Epoch 100 (train)0.8s + (eval)0.1s: train loss = 0.06000 = (mf)0.05022 + (embed)0.00979, recall = 0.08505, ndcg = 0.27417, precision = 0.26297, map = 0.04840
# Epoch 101 (train)0.8s: train loss = 0.06090 = (mf)0.05105 + (embed)0.00985
# Epoch 102 (train)0.8s: train loss = 0.05800 = (mf)0.04808 + (embed)0.00992
# Epoch 103 (train)0.8s: train loss = 0.05773 = (mf)0.04775 + (embed)0.00998
# Epoch 104 (train)0.8s: train loss = 0.05982 = (mf)0.04975 + (embed)0.01007
# Epoch 105 (train)0.8s + (eval)0.1s: train loss = 0.05786 = (mf)0.04774 + (embed)0.01012, recall = 0.08885, ndcg = 0.27340, precision = 0.26423, map = 0.04813
# Epoch 106 (train)0.8s: train loss = 0.05833 = (mf)0.04815 + (embed)0.01018
# Epoch 107 (train)0.8s: train loss = 0.05855 = (mf)0.04832 + (embed)0.01023
# Epoch 108 (train)0.8s: train loss = 0.05652 = (mf)0.04621 + (embed)0.01031
# Epoch 109 (train)0.8s: train loss = 0.05685 = (mf)0.04649 + (embed)0.01036
# Epoch 110 (train)0.8s + (eval)0.1s: train loss = 0.05711 = (mf)0.04667 + (embed)0.01044, recall = 0.08993, ndcg = 0.27736, precision = 0.26952, map = 0.04928
# Epoch 111 (train)0.8s: train loss = 0.05572 = (mf)0.04524 + (embed)0.01048
# Epoch 112 (train)0.8s: train loss = 0.05592 = (mf)0.04538 + (embed)0.01054
# Epoch 113 (train)0.8s: train loss = 0.05514 = (mf)0.04453 + (embed)0.01061
# Epoch 114 (train)0.8s: train loss = 0.05497 = (mf)0.04430 + (embed)0.01067
# Epoch 115 (train)0.8s + (eval)0.1s: train loss = 0.05410 = (mf)0.04337 + (embed)0.01073, recall = 0.09190, ndcg = 0.27712, precision = 0.26524, map = 0.04975
# Epoch 116 (train)0.8s: train loss = 0.05463 = (mf)0.04385 + (embed)0.01078
# Epoch 117 (train)0.8s: train loss = 0.05330 = (mf)0.04246 + (embed)0.01084
# Epoch 118 (train)0.8s: train loss = 0.05297 = (mf)0.04209 + (embed)0.01088
# Epoch 119 (train)0.8s: train loss = 0.05227 = (mf)0.04128 + (embed)0.01098
# Epoch 120 (train)0.8s + (eval)0.1s: train loss = 0.05215 = (mf)0.04111 + (embed)0.01104, recall = 0.09071, ndcg = 0.27736, precision = 0.26700, map = 0.04937
# Epoch 121 (train)0.8s: train loss = 0.05367 = (mf)0.04260 + (embed)0.01107
# Epoch 122 (train)0.8s: train loss = 0.05350 = (mf)0.04237 + (embed)0.01113
# Epoch 123 (train)0.8s: train loss = 0.05208 = (mf)0.04089 + (embed)0.01118
# Epoch 124 (train)0.8s: train loss = 0.05221 = (mf)0.04096 + (embed)0.01125
# Epoch 125 (train)0.8s + (eval)0.1s: train loss = 0.05152 = (mf)0.04026 + (embed)0.01126, recall = 0.08970, ndcg = 0.27533, precision = 0.26448, map = 0.04956
# Epoch 126 (train)0.8s: train loss = 0.05135 = (mf)0.04000 + (embed)0.01135
# Epoch 127 (train)0.8s: train loss = 0.05155 = (mf)0.04013 + (embed)0.01142
# Epoch 128 (train)0.8s: train loss = 0.05170 = (mf)0.04024 + (embed)0.01146
# Epoch 129 (train)0.8s: train loss = 0.05082 = (mf)0.03932 + (embed)0.01150
# Epoch 130 (train)0.8s + (eval)0.1s: train loss = 0.04926 = (mf)0.03767 + (embed)0.01158, recall = 0.09243, ndcg = 0.27837, precision = 0.26751, map = 0.05047
# Epoch 131 (train)0.8s: train loss = 0.04907 = (mf)0.03746 + (embed)0.01161
# Epoch 132 (train)0.8s: train loss = 0.04829 = (mf)0.03662 + (embed)0.01168
# Epoch 133 (train)0.8s: train loss = 0.04912 = (mf)0.03738 + (embed)0.01174
# Epoch 134 (train)0.8s: train loss = 0.04908 = (mf)0.03730 + (embed)0.01178
# Epoch 135 (train)0.8s + (eval)0.1s: train loss = 0.04848 = (mf)0.03665 + (embed)0.01183, recall = 0.09459, ndcg = 0.27988, precision = 0.27003, map = 0.05008
# Epoch 136 (train)0.8s: train loss = 0.04806 = (mf)0.03618 + (embed)0.01187
# Epoch 137 (train)0.8s: train loss = 0.04909 = (mf)0.03718 + (embed)0.01191
# Epoch 138 (train)0.8s: train loss = 0.04742 = (mf)0.03543 + (embed)0.01199
# Epoch 139 (train)0.8s: train loss = 0.04780 = (mf)0.03577 + (embed)0.01203
# Epoch 140 (train)0.8s + (eval)0.1s: train loss = 0.04733 = (mf)0.03527 + (embed)0.01206, recall = 0.09310, ndcg = 0.27600, precision = 0.26751, map = 0.04912
# Epoch 141 (train)0.8s: train loss = 0.04877 = (mf)0.03667 + (embed)0.01210
# Epoch 142 (train)0.8s: train loss = 0.04664 = (mf)0.03448 + (embed)0.01216
# Epoch 143 (train)0.8s: train loss = 0.04782 = (mf)0.03560 + (embed)0.01222
# Epoch 144 (train)0.8s: train loss = 0.04763 = (mf)0.03537 + (embed)0.01227
# Epoch 145 (train)0.8s + (eval)0.1s: train loss = 0.04615 = (mf)0.03384 + (embed)0.01231, recall = 0.09497, ndcg = 0.27451, precision = 0.26625, map = 0.04900
# Epoch 146 (train)0.8s: train loss = 0.04675 = (mf)0.03443 + (embed)0.01232
# Epoch 147 (train)0.8s: train loss = 0.04608 = (mf)0.03366 + (embed)0.01241
# Epoch 148 (train)0.8s: train loss = 0.04533 = (mf)0.03290 + (embed)0.01243
# Epoch 149 (train)0.8s: train loss = 0.04627 = (mf)0.03375 + (embed)0.01251
# Epoch 150 (train)0.8s + (eval)0.1s: train loss = 0.04651 = (mf)0.03396 + (embed)0.01255, recall = 0.09475, ndcg = 0.27678, precision = 0.26776, map = 0.04947
# Epoch 151 (train)0.8s: train loss = 0.04665 = (mf)0.03405 + (embed)0.01260
# Epoch 152 (train)0.8s: train loss = 0.04478 = (mf)0.03215 + (embed)0.01264
# Epoch 153 (train)0.8s: train loss = 0.04719 = (mf)0.03451 + (embed)0.01268
# Epoch 154 (train)0.8s: train loss = 0.04480 = (mf)0.03206 + (embed)0.01273
# Epoch 155 (train)0.8s + (eval)0.1s: train loss = 0.04616 = (mf)0.03337 + (embed)0.01279, recall = 0.09058, ndcg = 0.27717, precision = 0.26499, map = 0.04972
# Epoch 156 (train)0.8s: train loss = 0.04582 = (mf)0.03303 + (embed)0.01279
# Epoch 157 (train)0.8s: train loss = 0.04430 = (mf)0.03147 + (embed)0.01283
# Epoch 158 (train)0.8s: train loss = 0.04408 = (mf)0.03118 + (embed)0.01289
# Epoch 159 (train)0.8s: train loss = 0.04506 = (mf)0.03213 + (embed)0.01293
# Epoch 160 (train)0.8s + (eval)0.1s: train loss = 0.04463 = (mf)0.03167 + (embed)0.01296, recall = 0.09062, ndcg = 0.27060, precision = 0.25693, map = 0.04854
# Epoch 161 (train)0.8s: train loss = 0.04443 = (mf)0.03145 + (embed)0.01298
# Epoch 162 (train)0.8s: train loss = 0.04367 = (mf)0.03062 + (embed)0.01305
# Epoch 163 (train)0.8s: train loss = 0.04328 = (mf)0.03019 + (embed)0.01309
# Epoch 164 (train)0.8s: train loss = 0.04484 = (mf)0.03172 + (embed)0.01312
# Epoch 165 (train)0.8s + (eval)0.1s: train loss = 0.04441 = (mf)0.03122 + (embed)0.01319, recall = 0.09175, ndcg = 0.26856, precision = 0.25542, map = 0.04868
# Epoch 166 (train)0.8s: train loss = 0.04448 = (mf)0.03126 + (embed)0.01322
# Epoch 167 (train)0.8s: train loss = 0.04375 = (mf)0.03051 + (embed)0.01323
# Epoch 168 (train)0.8s: train loss = 0.04234 = (mf)0.02905 + (embed)0.01329
# Epoch 169 (train)0.8s: train loss = 0.04291 = (mf)0.02957 + (embed)0.01334
# Epoch 170 (train)0.8s + (eval)0.1s: train loss = 0.04138 = (mf)0.02801 + (embed)0.01337, recall = 0.09339, ndcg = 0.27360, precision = 0.26020, map = 0.05010
# Epoch 171 (train)0.8s: train loss = 0.04183 = (mf)0.02840 + (embed)0.01343
# Epoch 172 (train)0.8s: train loss = 0.04242 = (mf)0.02894 + (embed)0.01348
# Epoch 173 (train)0.8s: train loss = 0.04324 = (mf)0.02972 + (embed)0.01352
# Epoch 174 (train)0.8s: train loss = 0.04190 = (mf)0.02836 + (embed)0.01354
# Epoch 175 (train)0.8s + (eval)0.1s: train loss = 0.04149 = (mf)0.02790 + (embed)0.01360, recall = 0.09231, ndcg = 0.27070, precision = 0.26096, map = 0.04789
# Epoch 176 (train)0.8s: train loss = 0.04123 = (mf)0.02760 + (embed)0.01363
# Epoch 177 (train)0.8s: train loss = 0.04173 = (mf)0.02808 + (embed)0.01365
# Epoch 178 (train)0.8s: train loss = 0.04135 = (mf)0.02765 + (embed)0.01369
# Epoch 179 (train)0.8s: train loss = 0.04026 = (mf)0.02655 + (embed)0.01371
# Epoch 180 (train)0.8s + (eval)0.1s: train loss = 0.04113 = (mf)0.02736 + (embed)0.01377, recall = 0.09144, ndcg = 0.26898, precision = 0.25768, map = 0.04760
# Epoch 181 (train)0.8s: train loss = 0.04160 = (mf)0.02782 + (embed)0.01378
# Epoch 182 (train)0.8s: train loss = 0.04238 = (mf)0.02853 + (embed)0.01385
# Epoch 183 (train)0.8s: train loss = 0.04029 = (mf)0.02639 + (embed)0.01389
# Epoch 184 (train)0.8s: train loss = 0.04096 = (mf)0.02703 + (embed)0.01393
# Epoch 185 (train)0.8s + (eval)0.1s: train loss = 0.04073 = (mf)0.02677 + (embed)0.01396, recall = 0.08916, ndcg = 0.26749, precision = 0.25718, map = 0.04768
# Epoch 186 (train)0.8s: train loss = 0.04000 = (mf)0.02604 + (embed)0.01396
# Epoch 187 (train)0.8s: train loss = 0.04014 = (mf)0.02610 + (embed)0.01404
# Epoch 188 (train)0.8s: train loss = 0.04024 = (mf)0.02615 + (embed)0.01408
# Epoch 189 (train)0.8s: train loss = 0.04016 = (mf)0.02606 + (embed)0.01410
# Epoch 190 (train)0.8s + (eval)0.1s: train loss = 0.04063 = (mf)0.02649 + (embed)0.01414, recall = 0.09163, ndcg = 0.26784, precision = 0.25516, map = 0.04876
# Epoch 191 (train)0.8s: train loss = 0.03955 = (mf)0.02539 + (embed)0.01416
# Epoch 192 (train)0.8s: train loss = 0.03963 = (mf)0.02542 + (embed)0.01420
# Epoch 193 (train)0.8s: train loss = 0.03891 = (mf)0.02469 + (embed)0.01422
# Epoch 194 (train)0.8s: train loss = 0.03953 = (mf)0.02525 + (embed)0.01428
# Epoch 195 (train)0.8s + (eval)0.1s: train loss = 0.03925 = (mf)0.02497 + (embed)0.01428, recall = 0.08898, ndcg = 0.26961, precision = 0.25516, map = 0.04894
# Epoch 196 (train)0.8s: train loss = 0.03906 = (mf)0.02473 + (embed)0.01433
# Epoch 197 (train)0.8s: train loss = 0.03797 = (mf)0.02361 + (embed)0.01436
# Epoch 198 (train)0.8s: train loss = 0.03873 = (mf)0.02433 + (embed)0.01440
# Epoch 199 (train)0.8s: train loss = 0.03937 = (mf)0.02495 + (embed)0.01442
# Epoch 200 (train)0.8s + (eval)0.1s: train loss = 0.03933 = (mf)0.02487 + (embed)0.01446, recall = 0.09000, ndcg = 0.26706, precision = 0.25416, map = 0.04749
# Took 165.934860084 seconds for training.

# %% [markdown]
# ## 3 Prediction/Recommendation

# %% [markdown]
# Recommendation and evaluation have been performed on the specified test set during training. After training, we can also use the model to perform recommendation and evalution on other data. Here we still use `test` as test data, but `test` can be replaced by other data with similar data structure.
#
# We can call `recommend_k_items` to recommend k items for each user passed in this function. We set `remove_seen=True` to remove the items already seen by the user. The function returns a dataframe, containing each user and top k items recommended to them and the corresponding ranking scores.

# %%
with Timer() as test_time:
    topk_scores = model.recommend_k_items(test, top_k=TOP_K_SPLIT_TRAIN_TEST, remove_seen=True)
print("Took {} seconds for prediction.".format(test_time.interval))

topk_scores.head()
# Out:
# Took 0.029627250000004324 seconds for training.
#                                    userID                itemID  prediction
# 0  "01aa6102-a054-4f25-a747-a39a4ea86769"  Calcimax Tablets x30   10.448770
# 1  "01aa6102-a054-4f25-a747-a39a4ea86769"          Kiss Condoms    9.648853
# 2  "01aa6102-a054-4f25-a747-a39a4ea86769"            Ibucap x20    9.534927
# 3  "01aa6102-a054-4f25-a747-a39a4ea86769"   Danacid Tablets x96    9.446033
# 4  "01aa6102-a054-4f25-a747-a39a4ea86769"         Tab Boska x20    9.389656

# %% [markdown]
# ## 4 Evaluation
#
# With `topk_scores` predicted by the model, we can evaluate how LightGCN performs on this test set.

# %%
eval_map = map_at_k(test, topk_scores, k=TOP_K_SPLIT_TRAIN_TEST)
eval_ndcg = ndcg_at_k(test, topk_scores, k=TOP_K_SPLIT_TRAIN_TEST)
eval_precision = precision_at_k(test, topk_scores, k=TOP_K_SPLIT_TRAIN_TEST)
eval_recall = recall_at_k(test, topk_scores, k=TOP_K_SPLIT_TRAIN_TEST)

print("MAP:\t%f" % eval_map,
      "NDCG:\t%f" % eval_ndcg,
      "Precision@K:\t%f" % eval_precision,
      "Recall@K:\t%f" % eval_recall, sep='\n')
# Out:
# MAP:	0.047492
# NDCG:	0.267060
# Precision@K:	0.254156
# Recall@K:	0.089995

# %% [markdown]
# ## [Skipped] Infer embeddings
#
# With `infer_embedding` method of LightGCN model, we can export the embeddings of users and items in the training set to CSV files for future use.

# %%
# model.infer_embedding(user_file, item_file)

# %% [markdown]
# ## 5 Additional exploration

# %% [markdown]
# ### Revised/copied code from packages

# %%
import numpy as np


from recommenders.utils.constants import (
    DEFAULT_USER_COL,
    DEFAULT_ITEM_COL,
    DEFAULT_RATING_COL,
    DEFAULT_PREDICTION_COL,
    DEFAULT_RELEVANCE_COL,
    DEFAULT_SIMILARITY_COL,
    DEFAULT_ITEM_FEATURES_COL,
    DEFAULT_ITEM_SIM_MEASURE,
    DEFAULT_K,
    DEFAULT_THRESHOLD,
)


def _get_rating_column(relevancy_method: str, **kwargs) -> str:
    r"""Helper utility to simplify the arguments of eval metrics
    Attemtps to address https://github.com/microsoft/recommenders/issues/1737.

    Args:
        relevancy_method (str): method for determining relevancy ['top_k', 'by_threshold', None]. None means that the
            top k items are directly provided, so there is no need to compute the relevancy operation.

    Returns:
        str: rating column name.
    """
    if relevancy_method != "top_k":
        if "col_rating" not in kwargs:
            raise ValueError("Expected an argument `col_rating` but wasn't found.")
        col_rating = kwargs.get("col_rating")
    else:
        col_rating = kwargs.get("col_rating", DEFAULT_RATING_COL)
    return col_rating


def merge_ranking_true_pred(
    rating_true,
    rating_pred,
    col_user,
    col_item,
    col_rating,
    col_prediction,
    relevancy_method,
    k=DEFAULT_K,
    threshold=DEFAULT_THRESHOLD,
):
    """Filter truth and prediction data frames on common users

    Args:
        rating_true (pandas.DataFrame): True DataFrame
        rating_pred (pandas.DataFrame): Predicted DataFrame
        col_user (str): column name for user
        col_item (str): column name for item
        col_rating (str): column name for rating
        col_prediction (str): column name for prediction
        relevancy_method (str): method for determining relevancy ['top_k', 'by_threshold', None]. None means that the
            top k items are directly provided, so there is no need to compute the relevancy operation.
        k (int): number of top k items per user (optional)
        threshold (float): threshold of top items per user (optional)

    Returns:
        pandas.DataFrame, pandas.DataFrame, int: DataFrame of recommendation hits, sorted by `col_user` and `rank`
        DataFrame of hit counts vs actual relevant items per user number of unique user ids
    """

    # Make sure the prediction and true data frames have the same set of users
    common_users = set(rating_true[col_user]).intersection(set(rating_pred[col_user]))
    rating_true_common = rating_true[rating_true[col_user].isin(common_users)]
    rating_pred_common = rating_pred[rating_pred[col_user].isin(common_users)]
    n_users = len(common_users)

    # Return hit items in prediction data frame with ranking information. This is used for calculating NDCG and MAP.
    # Use first to generate unique ranking values for each item. This is to align with the implementation in
    # Spark evaluation metrics, where index of each recommended items (the indices are unique to items) is used
    # to calculate penalized precision of the ordered items.
    if relevancy_method == "top_k":
        top_k = k
    elif relevancy_method == "by_threshold":
        top_k = threshold
    elif relevancy_method is None:
        top_k = None
    else:
        raise NotImplementedError("Invalid relevancy_method")
    df_hit = get_top_k_items(
        dataframe=rating_pred_common,
        col_user=col_user,
        col_rating=col_prediction,
        k=top_k,
    )
    df_hit = pd.merge(df_hit, rating_true_common, on=[col_user, col_item])[
        [col_user, col_item, "rank"]
    ]

    # count the number of hits vs actual relevant items per user
    df_hit_count = pd.merge(
        df_hit.groupby(col_user, as_index=False)[col_user].agg({"hit": "count"}),
        rating_true_common.groupby(col_user, as_index=False)[col_user].agg(
            {"actual": "count"}
        ),
        on=col_user,
    )

    return df_hit, df_hit_count, n_users


def get_top_k_items(
    dataframe, col_user=DEFAULT_USER_COL, col_rating=DEFAULT_RATING_COL, k=DEFAULT_K
):
    """Get the input customer-item-rating tuple in the format of Pandas
    DataFrame, output a Pandas DataFrame in the dense format of top k items
    for each user.

    Note:
        If it is implicit rating, just append a column of constants to be
        ratings.

    Args:
        dataframe (pandas.DataFrame): DataFrame of rating data (in the format
        customerID-itemID-rating)
        col_user (str): column name for user
        col_rating (str): column name for rating
        k (int or None): number of items for each user; None means that the input has already been
        filtered out top k items and sorted by ratings and there is no need to do that again.

    Returns:
        pandas.DataFrame: DataFrame of top k items for each user, sorted by `col_user` and `rank`
    """
    # Sort dataframe by col_user and (top k) col_rating
    if k is None:
        top_k_items = dataframe
    else:
        top_k_items = (
            dataframe.sort_values([col_user, col_rating], ascending=[True, False])
            .groupby(col_user, as_index=False)
            .head(k)
            .reset_index(drop=True)
        )
    # Add ranks
    top_k_items["rank"] = top_k_items.groupby(col_user, sort=False).cumcount() + 1
    return top_k_items


def ndcg_at_k_hist(
    rating_true,
    rating_pred,
    col_user=DEFAULT_USER_COL,
    col_item=DEFAULT_ITEM_COL,
    col_prediction=DEFAULT_PREDICTION_COL,
    relevancy_method="top_k",
    k=DEFAULT_K,
    threshold=DEFAULT_THRESHOLD,
    score_type="binary",
    discfun_type="loge",
    **kwargs
):
    """Normalized Discounted Cumulative Gain (nDCG).

    Info: https://en.wikipedia.org/wiki/Discounted_cumulative_gain

    Args:
        rating_true (pandas.DataFrame): True DataFrame
        rating_pred (pandas.DataFrame): Predicted DataFrame
        col_user (str): column name for user
        col_item (str): column name for item
        col_rating (str): column name for rating
        col_prediction (str): column name for prediction
        relevancy_method (str): method for determining relevancy ['top_k', 'by_threshold', None]. None means that the
            top k items are directly provided, so there is no need to compute the relevancy operation.
        k (int): number of top k items per user
        threshold (float): threshold of top items per user (optional)
        score_type (str): type of relevance scores ['binary', 'raw', 'exp']. With the default option 'binary', the
            relevance score is reduced to either 1 (hit) or 0 (miss). Option 'raw' uses the raw relevance score.
            Option 'exp' uses (2 ** RAW_RELEVANCE - 1) as the relevance score
        discfun_type (str): type of discount function ['loge', 'log2'] used to calculate DCG.

    Returns:
        float: nDCG at k (min=0, max=1).
    """
    col_rating = _get_rating_column(relevancy_method, **kwargs)
    df_hit, _, _ = merge_ranking_true_pred(
        rating_true=rating_true,
        rating_pred=rating_pred,
        col_user=col_user,
        col_item=col_item,
        col_rating=col_rating,
        col_prediction=col_prediction,
        relevancy_method=relevancy_method,
        k=k,
        threshold=threshold,
    )

    if df_hit.shape[0] == 0:
        return 0.0

    df_dcg = df_hit.merge(rating_pred, on=[col_user, col_item]).merge(
        rating_true, on=[col_user, col_item], how="outer", suffixes=("_left", None)
    )

    if score_type == "binary":
        df_dcg["rel"] = 1
    elif score_type == "raw":
        df_dcg["rel"] = df_dcg[col_rating]
    elif score_type == "exp":
        df_dcg["rel"] = 2 ** df_dcg[col_rating] - 1
    else:
        raise ValueError("score_type must be one of 'binary', 'raw', 'exp'")

    if discfun_type == "loge":
        discfun = np.log
    elif discfun_type == "log2":
        discfun = np.log2
    else:
        raise ValueError("discfun_type must be one of 'loge', 'log2'")

    # Calculate the actual discounted gain for each record
    df_dcg["dcg"] = df_dcg["rel"] / discfun(1 + df_dcg["rank"])

    # Calculate the ideal discounted gain for each record
    df_idcg = df_dcg.sort_values([col_user, col_rating], ascending=False)
    df_idcg["irank"] = df_idcg.groupby(col_user, as_index=False, sort=False)[
        col_rating
    ].rank("first", ascending=False)
    df_idcg["idcg"] = df_idcg["rel"] / discfun(1 + df_idcg["irank"])

    # Calculate the actual DCG for each user
    df_user = df_dcg.groupby(col_user, as_index=False, sort=False).agg({"dcg": "sum"})

    # Calculate the ideal DCG for each user
    df_user = df_user.merge(
        df_idcg.groupby(col_user, as_index=False, sort=False)
        .head(k)
        .groupby(col_user, as_index=False, sort=False)
        .agg({"idcg": "sum"}),
        on=col_user,
    )

    # DCG over IDCG is the normalized DCG
    df_user["ndcg"] = df_user["dcg"] / df_user["idcg"]
    return df_user

# %% [markdown]
# ### nDCG per location histogram

# %%
# import matplotlib.pyplot as plt
# from matplotlib.ticker import PercentFormatter

# count_not_percentage = False
# eval_with_ndcg_hist = ndcg_at_k_hist(test, all_predictions, col_user='location_id', col_item='product', col_rating='sl_sold', col_prediction='prediction', k=TOP_K_SPLIT_TRAIN_TEST)
# eval_ndcg_hist = eval_with_ndcg_hist["ndcg"]

# if count_not_percentage:
#     plt.hist(eval_ndcg_hist, bins = np.linspace(0, 1, 11))
#     plt.ylabel("Frequency")
# else:
#     plt.hist(eval_ndcg_hist, bins = np.linspace(0, 1, 11),\
#          weights = np.ones(len(eval_ndcg_hist)) / len(eval_ndcg_hist))
#     plt.ylabel("Percentage in bin")
#     plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
# plt.title("nDCG per location")
# plt.xlabel("nDCG value")
# plt.show()
# print("Average nDCG over all locations: " + str(eval_ndcg_hist.mean()))

# %% [markdown]
# ### compute some stats

# %%
# n_locs_w_prod = {prod: 0 for prod in df_all_cols["product"]}
# n_prods_at_loc = {loc: 0 for loc in df_all_cols["location_id"]}
# membership = {}

# for _, row in df_all_cols.iterrows():
#     n_locs_w_prod[row["product"]] += 1
#     n_prods_at_loc[row["location_id"]] += 1
#     membership[row["location_id"]] = row["membership_type"]

# n_prods_at_loc_basic = {loc: n_prods for loc, n_prods in n_prods_at_loc.items() if membership[loc] == "basic"}

# n_locs = len(n_prods_at_loc)
# n_basic_locs = len(n_prods_at_loc_basic)

# print("Number of locations: " + str(n_locs))
# print("Number of basic locations: " + str(n_basic_locs))

# %% [markdown]
# ### nDCG vs # products at location

# %%
# eval_loc_ndcg_hist = eval_with_ndcg_hist[["location_id", "ndcg"]]
# eval_ndcg_hist_n_prods = eval_loc_ndcg_hist.join(pd.Series(n_prods_at_loc).to_frame("n_prods"), on = "location_id", how = "left")

# eval_ndcg_hist_n_prods.plot(x = "n_prods", y = "ndcg", style = "o", legend = None)
# plt.title("nDCG vs. # products for all locations")
# plt.xlabel("# products")
# plt.ylabel("nDCG")
# plt.show()

# %% [markdown]
# ### nDCG per location by number of products histogram

# %%
# min_n_prods_range = (0, 50, 100, 150, 200, 300, 400)
# max_n_prods_range = (50, 100, 150, 200, 300, 400, 500)
# count_not_percentage = False

# for (min_n_prods, max_n_prods) in zip(min_n_prods_range, max_n_prods_range):
#     eval_ndcg_hist_bounded_n_prods = eval_ndcg_hist_n_prods[(eval_ndcg_hist_n_prods["n_prods"] >= min_n_prods) & (eval_ndcg_hist_n_prods["n_prods"] < max_n_prods)]
#     eval_ndcg_hist_bounded_n_prods_ndcg_only = eval_ndcg_hist_bounded_n_prods["ndcg"]

#     if count_not_percentage:
#         plt.hist(eval_ndcg_hist_bounded_n_prods_ndcg_only, bins = np.linspace(0, 1, 11))
#         plt.ylabel("Frequency")
#     else:
#         plt.hist(eval_ndcg_hist_bounded_n_prods_ndcg_only, bins = np.linspace(0, 1, 11),\
#             weights = np.ones(len(eval_ndcg_hist_bounded_n_prods_ndcg_only)) / len(eval_ndcg_hist_bounded_n_prods_ndcg_only))
#         plt.ylabel("Percentage in bin")
#         plt.gca().yaxis.set_major_formatter(PercentFormatter(1))
#     plt.title("nDCG per location with # products in [" + str(min_n_prods) + ", " + str(max_n_prods) + ")")
#     plt.xlabel("nDCG value")
#     plt.show()
#     print("Average nDCG for locations with # products in [" + str(min_n_prods) + ", " + str(max_n_prods) + "): " + str(eval_ndcg_hist_bounded_n_prods_ndcg_only.mean()))

# %% [markdown]
# ## 6 Train, Predict, and Evaluate on Whole Dataset
#
# Earlier, we had split train (for model training) and test (for evaluation). In implementation, we have train = whole dataset, and we can evaluate on test = whole dataset.

# %%
#TOP_K_WHOLE = 10
#EXTRA_COLS = True

## Data
data_whole = ImplicitCF(train=df, test=df, seed=SEED)

## Hyperparameters
hparams = prepare_hparams(yaml_file,
                          n_layers=N_LAYERS,
                          batch_size=BATCH_SIZE,
                          epochs=EPOCHS,
                          learning_rate=LEARNING_RATE,
                          eval_epoch=EVAL_EPOCH,
                          top_k=TOP_K_WHOLE,
                         )

## Train
model_whole = LightGCN(hparams, data, seed=SEED)
with Timer() as train_time:
    model_whole.fit()
print("Took {} seconds for training.".format(train_time.interval))

## Predict
with Timer() as test_time:
    topk_scores_whole = model_whole.recommend_k_items(df, top_k=TOP_K_WHOLE, remove_seen=False)
print("Took {} seconds for prediction.".format(test_time.interval))

## Evaluate
eval_map_whole = map_at_k(df, topk_scores_whole, k=TOP_K_WHOLE)
eval_ndcg_whole = ndcg_at_k(df, topk_scores_whole, k=TOP_K_WHOLE)
eval_precision_whole = precision_at_k(df, topk_scores_whole, k=TOP_K_WHOLE)
eval_recall_whole = recall_at_k(df, topk_scores_whole, k=TOP_K_WHOLE)

print()
print("MAP:\t%f" % eval_map_whole,
      "NDCG:\t%f" % eval_ndcg_whole,
      "Precision@K:\t%f" % eval_precision_whole,
      "Recall@K:\t%f" % eval_recall_whole, sep='\n')

## Save recommendations
top_k_predictions_whole = get_top_k_items(topk_scores_whole, col_rating='prediction', k=TOP_K_WHOLE) # this adds a rank column
top_k_predictions_whole.drop("prediction", axis = 1, inplace = True)
# add column of true sales and rank of predicted products
top_all_true = get_top_k_items(df, k=df["itemID"].nunique())
top_k_predictions_whole = top_k_predictions_whole.merge(top_all_true, how = 'left', on = ['userID', 'itemID'], suffixes = (None, "_true"))
top_k_predictions_whole["rank_true"] = top_k_predictions_whole["rank_true"].convert_dtypes()
top_k_predictions_whole.rename(columns = {"itemID": "predicted product", "rating": "predicted product's true sales", "rank_true": "predicted product's true rank"}, inplace = True)
# add columns of true top-ranked products
top_all_true.rename(columns = {"itemID": "true product", "rating": "true product's sales"}, inplace = True)
top_k_predictions_whole = top_k_predictions_whole.merge(top_all_true, how = 'left', on = ['userID', 'rank'])
top_k_predictions_whole.rename(columns = {"userID": "location_id"}, inplace = True)
# reorder columns
top_k_predictions_whole = top_k_predictions_whole[["location_id", "rank", "true product", "true product's sales", "predicted product", "predicted product's true sales", "predicted product's true rank"]]
if EXTRA_COLS:
    # add column of fraction of locations selling predicted product
    top_k_predictions_whole["predicted product sells at fraction of locations"] = top_k_predictions_whole.apply(lambda row: round(n_locs_w_prod[row["predicted product"]] / n_locs, 2), axis = 1)
    # add column of average rank of predicted product at locations selling it
    prod_avg_rank = {prod: round(top_all_true[top_all_true["true product"] == prod]["rank"].mean()) for prod in n_locs_w_prod}
    top_k_predictions_whole["predicted product's average rank at locations selling it"] = top_k_predictions_whole.apply(lambda row: prod_avg_rank[row["predicted product"]], axis = 1)
    # save to csv
    top_k_predictions_whole.to_csv(THIS_ENGINE_NAME + "_" + COUNTRY + "_top_" + str(TOP_K_WHOLE) + "_prod_recs_extra_cols.csv")
else:
    top_k_predictions_whole.to_csv(THIS_ENGINE_NAME + "_" + COUNTRY + "_top_" + str(TOP_K_WHOLE) + "_prod_recs.csv")
# Out:
# /Users/DanielShen/opt/anaconda3/envs/microsoft_rec/lib/python3.8/site-packages/recommenders/models/deeprec/DataModel/ImplicitCF.py:73: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = train if test is None else train.append(test)
# Already create adjacency matrix.
# Already normalize adjacency matrix.
# Using xavier initialization.
# Epoch 1 (train)1.2s: train loss = 0.62339 = (mf)0.62332 + (embed)0.00007
# Epoch 2 (train)1.1s: train loss = 0.38218 = (mf)0.38179 + (embed)0.00039
# Epoch 3 (train)1.0s: train loss = 0.33754 = (mf)0.33695 + (embed)0.00059
# Epoch 4 (train)0.9s: train loss = 0.31578 = (mf)0.31511 + (embed)0.00067
# Epoch 5 (train)0.8s + (eval)0.3s: train loss = 0.28610 = (mf)0.28532 + (embed)0.00078, recall = 0.43669, ndcg = 0.31462, precision = 0.13217, map = 0.11405
# Epoch 6 (train)0.8s: train loss = 0.26641 = (mf)0.26550 + (embed)0.00092
# Epoch 7 (train)0.8s: train loss = 0.25709 = (mf)0.25605 + (embed)0.00104
# Epoch 8 (train)0.8s: train loss = 0.24585 = (mf)0.24469 + (embed)0.00116
# Epoch 9 (train)0.8s: train loss = 0.23449 = (mf)0.23321 + (embed)0.00128
# Epoch 10 (train)0.8s + (eval)0.2s: train loss = 0.22897 = (mf)0.22759 + (embed)0.00139, recall = 0.46592, ndcg = 0.33512, precision = 0.14078, map = 0.12640
# Epoch 11 (train)0.8s: train loss = 0.21681 = (mf)0.21531 + (embed)0.00151
# Epoch 12 (train)0.8s: train loss = 0.21540 = (mf)0.21378 + (embed)0.00162
# Epoch 13 (train)0.8s: train loss = 0.20736 = (mf)0.20563 + (embed)0.00173
# Epoch 14 (train)0.8s: train loss = 0.20088 = (mf)0.19904 + (embed)0.00184
# Epoch 15 (train)0.8s + (eval)0.2s: train loss = 0.19108 = (mf)0.18911 + (embed)0.00197, recall = 0.49334, ndcg = 0.35259, precision = 0.14952, map = 0.13777
# Epoch 16 (train)0.8s: train loss = 0.18523 = (mf)0.18313 + (embed)0.00210
# Epoch 17 (train)0.8s: train loss = 0.17853 = (mf)0.17630 + (embed)0.00222
# Epoch 18 (train)0.8s: train loss = 0.17167 = (mf)0.16933 + (embed)0.00234
# Epoch 19 (train)0.8s: train loss = 0.16579 = (mf)0.16333 + (embed)0.00246
# Epoch 20 (train)0.8s + (eval)0.2s: train loss = 0.16022 = (mf)0.15763 + (embed)0.00259, recall = 0.51486, ndcg = 0.36662, precision = 0.15433, map = 0.14605
# Epoch 21 (train)0.8s: train loss = 0.15910 = (mf)0.15636 + (embed)0.00274
# Epoch 22 (train)0.8s: train loss = 0.15496 = (mf)0.15210 + (embed)0.00286
# Epoch 23 (train)0.8s: train loss = 0.14888 = (mf)0.14590 + (embed)0.00298
# Epoch 24 (train)0.8s: train loss = 0.14446 = (mf)0.14136 + (embed)0.00310
# Epoch 25 (train)0.8s + (eval)0.2s: train loss = 0.14231 = (mf)0.13907 + (embed)0.00324, recall = 0.53261, ndcg = 0.37693, precision = 0.16008, map = 0.15319
# Epoch 26 (train)0.8s: train loss = 0.14066 = (mf)0.13729 + (embed)0.00337
# Epoch 27 (train)0.8s: train loss = 0.13714 = (mf)0.13366 + (embed)0.00349
# Epoch 28 (train)0.8s: train loss = 0.13683 = (mf)0.13324 + (embed)0.00360
# Epoch 29 (train)0.8s: train loss = 0.12798 = (mf)0.12427 + (embed)0.00371
# Epoch 30 (train)0.8s + (eval)0.2s: train loss = 0.12619 = (mf)0.12235 + (embed)0.00384, recall = 0.53335, ndcg = 0.38513, precision = 0.16254, map = 0.16105
# Epoch 31 (train)0.8s: train loss = 0.12500 = (mf)0.12105 + (embed)0.00395
# Epoch 32 (train)0.8s: train loss = 0.12254 = (mf)0.11849 + (embed)0.00405
# Epoch 33 (train)0.8s: train loss = 0.11891 = (mf)0.11473 + (embed)0.00418
# Epoch 34 (train)0.8s: train loss = 0.11913 = (mf)0.11485 + (embed)0.00428
# Epoch 35 (train)0.8s + (eval)0.2s: train loss = 0.11647 = (mf)0.11205 + (embed)0.00442, recall = 0.53892, ndcg = 0.38913, precision = 0.16479, map = 0.16258
# Epoch 36 (train)0.8s: train loss = 0.11212 = (mf)0.10761 + (embed)0.00451
# Epoch 37 (train)0.8s: train loss = 0.11177 = (mf)0.10717 + (embed)0.00461
# Epoch 38 (train)0.8s: train loss = 0.11525 = (mf)0.11053 + (embed)0.00472
# Epoch 39 (train)0.8s: train loss = 0.11087 = (mf)0.10606 + (embed)0.00481
# Epoch 40 (train)0.8s + (eval)0.2s: train loss = 0.10676 = (mf)0.10184 + (embed)0.00492, recall = 0.54625, ndcg = 0.39217, precision = 0.16599, map = 0.16389
# Epoch 41 (train)0.8s: train loss = 0.10642 = (mf)0.10141 + (embed)0.00501
# Epoch 42 (train)0.8s: train loss = 0.10316 = (mf)0.09803 + (embed)0.00513
# Epoch 43 (train)0.8s: train loss = 0.10258 = (mf)0.09735 + (embed)0.00523
# Epoch 44 (train)0.8s: train loss = 0.10258 = (mf)0.09726 + (embed)0.00531
# Epoch 45 (train)0.8s + (eval)0.2s: train loss = 0.10051 = (mf)0.09509 + (embed)0.00542, recall = 0.54432, ndcg = 0.39208, precision = 0.16605, map = 0.16474
# Epoch 46 (train)0.8s: train loss = 0.09790 = (mf)0.09239 + (embed)0.00551
# Epoch 47 (train)0.8s: train loss = 0.09930 = (mf)0.09369 + (embed)0.00561
# Epoch 48 (train)0.8s: train loss = 0.09982 = (mf)0.09412 + (embed)0.00570
# Epoch 49 (train)0.8s: train loss = 0.09843 = (mf)0.09265 + (embed)0.00578
# Epoch 50 (train)0.8s + (eval)0.2s: train loss = 0.09273 = (mf)0.08684 + (embed)0.00588, recall = 0.54445, ndcg = 0.39479, precision = 0.16635, map = 0.16795
# Epoch 51 (train)0.8s: train loss = 0.09362 = (mf)0.08766 + (embed)0.00596
# Epoch 52 (train)0.8s: train loss = 0.09292 = (mf)0.08685 + (embed)0.00606
# Epoch 53 (train)0.8s: train loss = 0.09259 = (mf)0.08643 + (embed)0.00616
# Epoch 54 (train)0.8s: train loss = 0.09278 = (mf)0.08654 + (embed)0.00624
# Epoch 55 (train)0.8s + (eval)0.2s: train loss = 0.08952 = (mf)0.08321 + (embed)0.00632, recall = 0.54035, ndcg = 0.39380, precision = 0.16635, map = 0.16671
# Epoch 56 (train)0.8s: train loss = 0.08990 = (mf)0.08349 + (embed)0.00641
# Epoch 57 (train)0.8s: train loss = 0.08871 = (mf)0.08220 + (embed)0.00651
# Epoch 58 (train)0.8s: train loss = 0.08729 = (mf)0.08070 + (embed)0.00660
# Epoch 59 (train)0.8s: train loss = 0.08511 = (mf)0.07840 + (embed)0.00670
# Epoch 60 (train)0.8s + (eval)0.2s: train loss = 0.08640 = (mf)0.07963 + (embed)0.00677, recall = 0.54288, ndcg = 0.39446, precision = 0.16678, map = 0.16853
# Epoch 61 (train)0.8s: train loss = 0.08483 = (mf)0.07798 + (embed)0.00685
# Epoch 62 (train)0.8s: train loss = 0.08407 = (mf)0.07714 + (embed)0.00693
# Epoch 63 (train)0.8s: train loss = 0.08460 = (mf)0.07760 + (embed)0.00700
# Epoch 64 (train)0.8s: train loss = 0.08242 = (mf)0.07533 + (embed)0.00709
# Epoch 65 (train)0.8s + (eval)0.2s: train loss = 0.07966 = (mf)0.07248 + (embed)0.00718, recall = 0.53953, ndcg = 0.39332, precision = 0.16607, map = 0.16848
# Epoch 66 (train)0.8s: train loss = 0.07862 = (mf)0.07135 + (embed)0.00727
# Epoch 67 (train)0.8s: train loss = 0.08282 = (mf)0.07547 + (embed)0.00735
# Epoch 68 (train)0.8s: train loss = 0.07756 = (mf)0.07014 + (embed)0.00742
# Epoch 69 (train)0.8s: train loss = 0.07819 = (mf)0.07066 + (embed)0.00753
# Epoch 70 (train)0.8s + (eval)0.2s: train loss = 0.07905 = (mf)0.07150 + (embed)0.00755, recall = 0.54253, ndcg = 0.39400, precision = 0.16625, map = 0.16758
# Epoch 71 (train)0.8s: train loss = 0.07473 = (mf)0.06706 + (embed)0.00767
# Epoch 72 (train)0.8s: train loss = 0.07438 = (mf)0.06664 + (embed)0.00774
# Epoch 73 (train)0.8s: train loss = 0.07441 = (mf)0.06660 + (embed)0.00781
# Epoch 74 (train)0.8s: train loss = 0.07297 = (mf)0.06507 + (embed)0.00790
# Epoch 75 (train)0.8s + (eval)0.2s: train loss = 0.07545 = (mf)0.06748 + (embed)0.00796, recall = 0.54500, ndcg = 0.39337, precision = 0.16582, map = 0.16699
# Epoch 76 (train)0.8s: train loss = 0.07321 = (mf)0.06514 + (embed)0.00807
# Epoch 77 (train)0.8s: train loss = 0.07531 = (mf)0.06717 + (embed)0.00814
# Epoch 78 (train)0.8s: train loss = 0.07338 = (mf)0.06519 + (embed)0.00820
# Epoch 79 (train)0.8s: train loss = 0.07186 = (mf)0.06358 + (embed)0.00827
# Epoch 80 (train)0.8s + (eval)0.2s: train loss = 0.07153 = (mf)0.06317 + (embed)0.00836, recall = 0.53782, ndcg = 0.39191, precision = 0.16627, map = 0.16644
# Epoch 81 (train)0.8s: train loss = 0.06979 = (mf)0.06133 + (embed)0.00846
# Epoch 82 (train)0.8s: train loss = 0.07037 = (mf)0.06185 + (embed)0.00853
# Epoch 83 (train)0.8s: train loss = 0.06927 = (mf)0.06070 + (embed)0.00857
# Epoch 84 (train)0.8s: train loss = 0.06704 = (mf)0.05835 + (embed)0.00869
# Epoch 85 (train)0.8s + (eval)0.2s: train loss = 0.06736 = (mf)0.05863 + (embed)0.00873, recall = 0.54220, ndcg = 0.39381, precision = 0.16710, map = 0.16795
# Epoch 86 (train)0.8s: train loss = 0.06753 = (mf)0.05871 + (embed)0.00882
# Epoch 87 (train)0.8s: train loss = 0.06775 = (mf)0.05885 + (embed)0.00890
# Epoch 88 (train)0.8s: train loss = 0.06563 = (mf)0.05667 + (embed)0.00895
# Epoch 89 (train)0.8s: train loss = 0.06532 = (mf)0.05627 + (embed)0.00905
# Epoch 90 (train)0.8s + (eval)0.2s: train loss = 0.06567 = (mf)0.05656 + (embed)0.00911, recall = 0.53872, ndcg = 0.39246, precision = 0.16662, map = 0.16826
# Epoch 91 (train)0.8s: train loss = 0.06336 = (mf)0.05418 + (embed)0.00918
# Epoch 92 (train)0.8s: train loss = 0.06393 = (mf)0.05468 + (embed)0.00926
# Epoch 93 (train)0.8s: train loss = 0.06502 = (mf)0.05573 + (embed)0.00929
# Epoch 94 (train)0.8s: train loss = 0.06531 = (mf)0.05593 + (embed)0.00938
# Epoch 95 (train)0.8s + (eval)0.2s: train loss = 0.06401 = (mf)0.05456 + (embed)0.00945, recall = 0.53445, ndcg = 0.38846, precision = 0.16529, map = 0.16466
# Epoch 96 (train)0.8s: train loss = 0.06442 = (mf)0.05490 + (embed)0.00951
# Epoch 97 (train)0.8s: train loss = 0.06180 = (mf)0.05223 + (embed)0.00958
# Epoch 98 (train)0.8s: train loss = 0.06072 = (mf)0.05105 + (embed)0.00967
# Epoch 99 (train)0.8s: train loss = 0.05976 = (mf)0.05005 + (embed)0.00971
# Epoch 100 (train)0.8s + (eval)0.2s: train loss = 0.06086 = (mf)0.05107 + (embed)0.00978, recall = 0.53416, ndcg = 0.38916, precision = 0.16582, map = 0.16618
# Epoch 101 (train)0.8s: train loss = 0.06142 = (mf)0.05158 + (embed)0.00984
# Epoch 102 (train)0.8s: train loss = 0.05844 = (mf)0.04852 + (embed)0.00992
# Epoch 103 (train)0.8s: train loss = 0.05723 = (mf)0.04726 + (embed)0.00997
# Epoch 104 (train)0.8s: train loss = 0.05928 = (mf)0.04922 + (embed)0.01006
# Epoch 105 (train)0.8s + (eval)0.2s: train loss = 0.05813 = (mf)0.04802 + (embed)0.01011, recall = 0.53248, ndcg = 0.38642, precision = 0.16411, map = 0.16381
# Epoch 106 (train)0.8s: train loss = 0.05845 = (mf)0.04827 + (embed)0.01017
# Epoch 107 (train)0.8s: train loss = 0.05796 = (mf)0.04774 + (embed)0.01022
# Epoch 108 (train)0.8s: train loss = 0.05691 = (mf)0.04661 + (embed)0.01030
# Epoch 109 (train)0.8s: train loss = 0.05669 = (mf)0.04634 + (embed)0.01035
# Epoch 110 (train)0.8s + (eval)0.2s: train loss = 0.05719 = (mf)0.04676 + (embed)0.01043, recall = 0.53571, ndcg = 0.38858, precision = 0.16559, map = 0.16533
# Epoch 111 (train)0.8s: train loss = 0.05647 = (mf)0.04600 + (embed)0.01048
# Epoch 112 (train)0.8s: train loss = 0.05595 = (mf)0.04543 + (embed)0.01053
# Epoch 113 (train)0.8s: train loss = 0.05501 = (mf)0.04441 + (embed)0.01060
# Epoch 114 (train)0.8s: train loss = 0.05481 = (mf)0.04414 + (embed)0.01066
# Epoch 115 (train)0.8s + (eval)0.2s: train loss = 0.05359 = (mf)0.04286 + (embed)0.01073, recall = 0.53218, ndcg = 0.38761, precision = 0.16499, map = 0.16497
# Epoch 116 (train)0.8s: train loss = 0.05476 = (mf)0.04398 + (embed)0.01078
# Epoch 117 (train)0.8s: train loss = 0.05386 = (mf)0.04303 + (embed)0.01083
# Epoch 118 (train)0.8s: train loss = 0.05360 = (mf)0.04272 + (embed)0.01087
# Epoch 119 (train)0.8s: train loss = 0.05246 = (mf)0.04148 + (embed)0.01097
# Epoch 120 (train)0.8s + (eval)0.2s: train loss = 0.05293 = (mf)0.04190 + (embed)0.01103, recall = 0.53123, ndcg = 0.38620, precision = 0.16448, map = 0.16418
# Epoch 121 (train)0.8s: train loss = 0.05396 = (mf)0.04290 + (embed)0.01106
# Epoch 122 (train)0.8s: train loss = 0.05365 = (mf)0.04252 + (embed)0.01112
# Epoch 123 (train)0.8s: train loss = 0.05187 = (mf)0.04070 + (embed)0.01117
# Epoch 124 (train)0.8s: train loss = 0.05273 = (mf)0.04150 + (embed)0.01124
# Epoch 125 (train)0.8s + (eval)0.2s: train loss = 0.05179 = (mf)0.04054 + (embed)0.01125, recall = 0.52788, ndcg = 0.38367, precision = 0.16317, map = 0.16226
# Epoch 126 (train)0.8s: train loss = 0.05146 = (mf)0.04012 + (embed)0.01134
# Epoch 127 (train)0.8s: train loss = 0.05195 = (mf)0.04054 + (embed)0.01141
# Epoch 128 (train)0.8s: train loss = 0.05252 = (mf)0.04107 + (embed)0.01145
# Epoch 129 (train)0.8s: train loss = 0.05117 = (mf)0.03968 + (embed)0.01149
# Epoch 130 (train)0.8s + (eval)0.2s: train loss = 0.04960 = (mf)0.03803 + (embed)0.01157, recall = 0.52920, ndcg = 0.38510, precision = 0.16317, map = 0.16282
# Epoch 131 (train)0.8s: train loss = 0.04939 = (mf)0.03779 + (embed)0.01160
# Epoch 132 (train)0.8s: train loss = 0.04855 = (mf)0.03690 + (embed)0.01166
# Epoch 133 (train)0.8s: train loss = 0.04994 = (mf)0.03822 + (embed)0.01172
# Epoch 134 (train)0.8s: train loss = 0.04917 = (mf)0.03741 + (embed)0.01176
# Epoch 135 (train)0.8s + (eval)0.2s: train loss = 0.04851 = (mf)0.03670 + (embed)0.01181, recall = 0.52722, ndcg = 0.38374, precision = 0.16292, map = 0.16238
# Epoch 136 (train)0.8s: train loss = 0.04793 = (mf)0.03608 + (embed)0.01185
# Epoch 137 (train)0.8s: train loss = 0.04858 = (mf)0.03669 + (embed)0.01189
# Epoch 138 (train)0.8s: train loss = 0.04780 = (mf)0.03582 + (embed)0.01198
# Epoch 139 (train)0.8s: train loss = 0.04751 = (mf)0.03551 + (embed)0.01201
# Epoch 140 (train)0.8s + (eval)0.2s: train loss = 0.04754 = (mf)0.03549 + (embed)0.01205, recall = 0.52786, ndcg = 0.38315, precision = 0.16327, map = 0.16252
# Epoch 141 (train)0.8s: train loss = 0.04950 = (mf)0.03741 + (embed)0.01209
# Epoch 142 (train)0.8s: train loss = 0.04753 = (mf)0.03539 + (embed)0.01214
# Epoch 143 (train)0.8s: train loss = 0.04851 = (mf)0.03630 + (embed)0.01220
# Epoch 144 (train)0.8s: train loss = 0.04756 = (mf)0.03532 + (embed)0.01225
# Epoch 145 (train)0.8s + (eval)0.2s: train loss = 0.04658 = (mf)0.03429 + (embed)0.01229, recall = 0.52489, ndcg = 0.38086, precision = 0.16257, map = 0.16026
# Epoch 146 (train)0.8s: train loss = 0.04709 = (mf)0.03479 + (embed)0.01231
# Epoch 147 (train)0.8s: train loss = 0.04609 = (mf)0.03370 + (embed)0.01239
# Epoch 148 (train)0.8s: train loss = 0.04605 = (mf)0.03363 + (embed)0.01241
# Epoch 149 (train)0.8s: train loss = 0.04697 = (mf)0.03448 + (embed)0.01249
# Epoch 150 (train)0.8s + (eval)0.2s: train loss = 0.04712 = (mf)0.03459 + (embed)0.01253, recall = 0.52124, ndcg = 0.37880, precision = 0.16214, map = 0.15972
# Epoch 151 (train)0.8s: train loss = 0.04691 = (mf)0.03433 + (embed)0.01257
# Epoch 152 (train)0.8s: train loss = 0.04550 = (mf)0.03289 + (embed)0.01261
# Epoch 153 (train)0.8s: train loss = 0.04780 = (mf)0.03515 + (embed)0.01264
# Epoch 154 (train)0.8s: train loss = 0.04500 = (mf)0.03230 + (embed)0.01270
# Epoch 155 (train)0.8s + (eval)0.2s: train loss = 0.04624 = (mf)0.03349 + (embed)0.01275, recall = 0.52187, ndcg = 0.38032, precision = 0.16217, map = 0.16069
# Epoch 156 (train)0.8s: train loss = 0.04576 = (mf)0.03301 + (embed)0.01275
# Epoch 157 (train)0.8s: train loss = 0.04351 = (mf)0.03071 + (embed)0.01280
# Epoch 158 (train)0.8s: train loss = 0.04510 = (mf)0.03224 + (embed)0.01286
# Epoch 159 (train)0.8s: train loss = 0.04510 = (mf)0.03220 + (embed)0.01290
# Epoch 160 (train)0.8s + (eval)0.2s: train loss = 0.04514 = (mf)0.03222 + (embed)0.01292, recall = 0.51721, ndcg = 0.37811, precision = 0.16118, map = 0.15868
# Epoch 161 (train)0.8s: train loss = 0.04492 = (mf)0.03197 + (embed)0.01295
# Epoch 162 (train)0.8s: train loss = 0.04454 = (mf)0.03153 + (embed)0.01301
# Epoch 163 (train)0.8s: train loss = 0.04301 = (mf)0.02996 + (embed)0.01305
# Epoch 164 (train)0.8s: train loss = 0.04473 = (mf)0.03165 + (embed)0.01308
# Epoch 165 (train)0.8s + (eval)0.2s: train loss = 0.04383 = (mf)0.03067 + (embed)0.01316, recall = 0.51516, ndcg = 0.37542, precision = 0.15995, map = 0.15696
# Epoch 166 (train)0.8s: train loss = 0.04525 = (mf)0.03207 + (embed)0.01318
# Epoch 167 (train)0.8s: train loss = 0.04432 = (mf)0.03112 + (embed)0.01320
# Epoch 168 (train)0.8s: train loss = 0.04303 = (mf)0.02977 + (embed)0.01326
# Epoch 169 (train)0.8s: train loss = 0.04405 = (mf)0.03075 + (embed)0.01330
# Epoch 170 (train)0.8s + (eval)0.2s: train loss = 0.04233 = (mf)0.02900 + (embed)0.01333, recall = 0.51807, ndcg = 0.37702, precision = 0.16128, map = 0.15787
# Epoch 171 (train)0.8s: train loss = 0.04234 = (mf)0.02895 + (embed)0.01339
# Epoch 172 (train)0.8s: train loss = 0.04316 = (mf)0.02972 + (embed)0.01344
# Epoch 173 (train)0.8s: train loss = 0.04405 = (mf)0.03058 + (embed)0.01347
# Epoch 174 (train)0.8s: train loss = 0.04224 = (mf)0.02876 + (embed)0.01349
# Epoch 175 (train)0.8s + (eval)0.2s: train loss = 0.04210 = (mf)0.02856 + (embed)0.01354, recall = 0.51564, ndcg = 0.37440, precision = 0.16043, map = 0.15703
# Epoch 176 (train)0.8s: train loss = 0.04169 = (mf)0.02811 + (embed)0.01357
# Epoch 177 (train)0.8s: train loss = 0.04226 = (mf)0.02866 + (embed)0.01359
# Epoch 178 (train)0.8s: train loss = 0.04130 = (mf)0.02766 + (embed)0.01365
# Epoch 179 (train)0.8s: train loss = 0.04021 = (mf)0.02656 + (embed)0.01366
# Epoch 180 (train)0.8s + (eval)0.2s: train loss = 0.04154 = (mf)0.02782 + (embed)0.01372, recall = 0.51410, ndcg = 0.37402, precision = 0.16008, map = 0.15599
# Epoch 181 (train)0.8s: train loss = 0.04233 = (mf)0.02860 + (embed)0.01373
# Epoch 182 (train)0.8s: train loss = 0.04365 = (mf)0.02985 + (embed)0.01380
# Epoch 183 (train)0.8s: train loss = 0.04174 = (mf)0.02790 + (embed)0.01384
# Epoch 184 (train)0.8s: train loss = 0.04101 = (mf)0.02714 + (embed)0.01387
# Epoch 185 (train)0.8s + (eval)0.2s: train loss = 0.04187 = (mf)0.02798 + (embed)0.01390, recall = 0.51084, ndcg = 0.37162, precision = 0.15922, map = 0.15468
# Epoch 186 (train)0.8s: train loss = 0.04038 = (mf)0.02648 + (embed)0.01390
# Epoch 187 (train)0.8s: train loss = 0.04063 = (mf)0.02665 + (embed)0.01398
# Epoch 188 (train)0.8s: train loss = 0.04049 = (mf)0.02647 + (embed)0.01402
# Epoch 189 (train)0.8s: train loss = 0.04082 = (mf)0.02679 + (embed)0.01403
# Epoch 190 (train)0.8s + (eval)0.2s: train loss = 0.04121 = (mf)0.02713 + (embed)0.01408, recall = 0.51027, ndcg = 0.37190, precision = 0.15950, map = 0.15512
# Epoch 191 (train)0.8s: train loss = 0.03950 = (mf)0.02541 + (embed)0.01410
# Epoch 192 (train)0.8s: train loss = 0.03996 = (mf)0.02582 + (embed)0.01414
# Epoch 193 (train)0.8s: train loss = 0.04055 = (mf)0.02640 + (embed)0.01415
# Epoch 194 (train)0.8s: train loss = 0.04047 = (mf)0.02626 + (embed)0.01421
# Epoch 195 (train)0.8s + (eval)0.2s: train loss = 0.04049 = (mf)0.02628 + (embed)0.01421, recall = 0.51247, ndcg = 0.37322, precision = 0.16000, map = 0.15651
# Epoch 196 (train)0.8s: train loss = 0.03945 = (mf)0.02519 + (embed)0.01426
# Epoch 197 (train)0.8s: train loss = 0.03862 = (mf)0.02433 + (embed)0.01429
# Epoch 198 (train)0.8s: train loss = 0.03928 = (mf)0.02495 + (embed)0.01433
# Epoch 199 (train)0.8s: train loss = 0.03993 = (mf)0.02559 + (embed)0.01434
# Epoch 200 (train)0.8s + (eval)0.2s: train loss = 0.03941 = (mf)0.02502 + (embed)0.01439, recall = 0.51066, ndcg = 0.37333, precision = 0.15919, map = 0.15583
# Took 164.46072741599997 seconds for training.
#
# MAP:	0.644208
# NDCG:	0.882344
# Precision@K:	0.622586
# Recall@K:	0.690722
